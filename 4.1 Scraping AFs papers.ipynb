# %% [markdown]
# # Parsing content from the web
#
# For our first task today, we will parse all available research papers from the professor's website!
#
# ### requests and .get( )
# The first thing we need to do is grab the html content of my webpage
# - we will use the requests module to grab my website content
# - we will set the my_headers variable to indicate to the server that we are accessing it as if we were using the Chrome browser
#
# Then we will simply request the page until we get it, or until we fail 5 times
#
# ###  try-except
# The try-except combo is very useful because it allows us to "catch" errors
# - Python first executes the code block of the "try" command
# - If the requests.get(url,headers = my_headers) is successfull, we execute the break command, and get out of the loop
# - If the requests.get(url,headers = my_headers) fails, python ignores all commands that are after it in the same code block, and instead executes the code block of the "except" command.

# %%
import requests
import time

url        = "http://www.apostolos-filippas.com/"
my_headers = { 'User-Agent':'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'}

success=False
    
# try 5 times
for i in range(1,6):
    try:           
        #use the browser to access the url  
        response=requests.get(url,headers = my_headers)              
        # if an error does not occur, set success 
        success=True 
        print( 'Successfully retrieved the webpage!')
        # we got the file, break the loop
        break        
    except:
        # if we got an exception, the attempt to get the response failed
        print ('failed attempt',i)
        # wait for 2 seconds before you go to the next iteration of the loop
        time.sleep(2)
# Out:
# Successfully retrieved the webpage!

# %% [markdown]
# Try to retrieve a url that does not exist, such as "http://www.apostolos-filippas-sucks.com/" and see what happens.
#
# Notes on requests:
# - To make sure that the website is accessed correctly, we can check we got a 200 OK response by running print(response.status_code)
# - We can check the http headers by print(result.headers). For example, we'll see the domain where the website is hosted
#
#
#
# ### Parsing the content
#
# Now grab the html text from the website that you got.

# %%
text = response.text
print(text)
# Out:
# <!doctype html>
# <html lang="en-US">
#
# <head>
# 	<meta name="google-site-verification" content="GdgYVZWetu8ZLgkJNbSyg9K8Hi5eV9t0k8NeCGcEJpo" />
# 	<meta charset="utf-8">
# 	<meta http-equiv="Content-Type" content="text/html">
# 	<title>Apostolos Filippas</title>
# 	<link rel="shortcut icon" href="http://people.stern.nyu.edu/afilippa/favicon.ico">
# 	<link rel="icon" href="http://people.stern.nyu.edu/afilippa/favicon.ico">
# 	<link rel="stylesheet" type="text/css" media="all" href="css/main.css">
#
# 	<link rel="stylesheet" href="http://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.4.0/css/font-awesome.min.css">
# 	<script src="http://code.jquery.com/jquery-2.1.4.min.js"></script>
#
# 	<!-- for older browser matchmedia support, only loads if support is missing -->
# 	<script src="js/matchMedia.js"></script>
#
# 	<script src="js/main.js"></script>
#
# </head>
#
# <body>
# 	<header class="site-header">
# 		<nav class="site-nav">
# 			<ul>
# ...

# %% [markdown]
# This is the same thing that you'd see if you went to my website, right-clicked and then clicked on "View page source"
#
#
# ### Grabbing information with regular expressions
#
# We can now use regular expressions to extract the pattern that we need. The following pattern will extract all patterns such as
# - papers/bigcounter.pdf">Strength in numbers: Using big data to simplify sentiment classification<
# - papers/sharing.pdf">Owning, using and renting: Some simple economics of the "sharing economy"<
# and so on
#
# Two things to remember
# - .+ indicates any string of lenght >=1
# - ( ) tells regular expressions which part of the pattern will be returned

# %%
import re
papers = re.findall('papers/.+>(.+)<' ,text)
print(papers)
# Out:
# ['The tragedy of your upstairs neighbors: Externalities of home-sharing', 'Reputation inflation', 'Managing market mechanism transitions: Evidence from a field experiment', 'Owning, using and renting: Some simple economics of the "sharing economy"', 'Strength in numbers: Using big data to simplify sentiment classification']

# %% [markdown]
# ### Challenge:
# TBA
